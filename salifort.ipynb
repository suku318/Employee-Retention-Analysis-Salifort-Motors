# %% [markdown]
# # Employee-Retention-Analysis-Salifort-Motors

# %% [markdown]
# ### Import the Packages

# %%
conda install -c conda-forge xgboost
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\sukhm\anaconda3
#
#   added / updated specs:
#     - xgboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2026.2.25  |       h4c7d964_0         144 KB  conda-forge
#     certifi-2026.2.25          |     pyhd8ed1ab_0         148 KB  conda-forge
#     conda-26.1.1               |  py313hfa70ccb_0         1.2 MB  conda-forge
#     libxgboost-3.2.0           |   cpu_h6b7513e_1         2.5 MB
#     openssl-3.6.2              |       hf411b9b_0         9.0 MB  conda-forge
#     py-xgboost-3.2.0           | cpu_pyh718b53a_1         168 KB  conda-forge
#     xgboost-3.2.0              | cpu_pyhb39878e_1          15 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        13.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   libxgboost         pkgs/main/win-64::libxgboost-3.2.0-cpu_h6b7513e_1
#   py-xgboost         conda-forge/noarch::py-xgboost-3.2.0-cpu_pyh718b53a_1
#   xgboost            conda-forge/noarch::xgboost-3.2.0-cpu_pyhb39878e_1
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main/win-64::ca-certificates-202~ --> conda-forge/noarch::ca-certificates-2026.2.25-h4c7d964_0
#   certifi            pkgs/main/win-64::certifi-2025.11.12-~ --> conda-forge/noarch::certifi-2026.2.25-pyhd8ed1ab_0
#   conda              pkgs/main::conda-25.11.0-py313haa9553~ --> conda-forge::conda-26.1.1-py313hfa70ccb_0
#   openssl              pkgs/main::openssl-3.0.18-h543e019_0 --> conda-forge::openssl-3.6.2-hf411b9b_0
#
#
#
# Downloading and Extracting Packages: ...working...
# openssl-3.6.2        | 9.0 MB    |            |   0%
#
# libxgboost-3.2.0     | 2.5 MB    |            |   0%
#
#
# conda-26.1.1         | 1.2 MB    |            |   0%
#
#
#
# py-xgboost-3.2.0     | 168 KB    |            |   0%
#
#
#
#
# certifi-2026.2.25    | 148 KB    |            |   0%
#
#
#
#
#
# ca-certificates-2026 | 144 KB    |            |   0%
#
#
#
#
#
#
# xgboost-3.2.0        | 15 KB     |            |   0%
# openssl-3.6.2        | 9.0 MB    |            |   0%
#
#
#
# py-xgboost-3.2.0     | 168 KB    | 9          |  10%
# openssl-3.6.2        | 9.0 MB    | 1          |   1%
# openssl-3.6.2        | 9.0 MB    | 1          |   2%
#
#
#
# py-xgboost-3.2.0     | 168 KB    | ######6    |  67%
#
#
#
# py-xgboost-3.2.0     | 168 KB    | ########## | 100%
#
#
# conda-26.1.1         | 1.2 MB    | 1          |   1%
# openssl-3.6.2        | 9.0 MB    | 2          |   3%
#
#
#
# py-xgboost-3.2.0     | 168 KB    | ########## | 100%
#
#
#
# py-xgboost-3.2.0     | 168 KB    | ########## | 100%
#
#
#
#
# certifi-2026.2.25    | 148 KB    | #          |  11%
#
#
# conda-26.1.1         | 1.2 MB    | 5          |   5%
# openssl-3.6.2        | 9.0 MB    | 3          |   4%
#
#
#
#
# certifi-2026.2.25    | 148 KB    | ####3      |  43%
#
#
#
#
#
# ca-certificates-2026 | 144 KB    | #1         |  11%
#
#
#
#
# certifi-2026.2.25    | 148 KB    | ######4    |  65%
#
# libxgboost-3.2.0     | 2.5 MB    |            |   1%
#
#
# conda-26.1.1         | 1.2 MB    | #          |  10%
# openssl-3.6.2        | 9.0 MB    | 4          |   5%
# openssl-3.6.2        | 9.0 MB    | 5          |   5%
#
#
#
#
# certifi-2026.2.25    | 148 KB    | ########6  |  87%
#
#
#
#
#
# ca-certificates-2026 | 144 KB    | ######6    |  67%
#
#
#
#
# certifi-2026.2.25    | 148 KB    | ########## | 100%
#
#
#
#
#
# ca-certificates-2026 | 144 KB    | ########## | 100%
#
#
# conda-26.1.1         | 1.2 MB    | #5         |  15%
#
# libxgboost-3.2.0     | 2.5 MB    | 2          |   2%
# openssl-3.6.2        | 9.0 MB    | 5          |   6%
#
#
#
#
#
# ca-certificates-2026 | 144 KB    | ########## | 100%
#
#
#
#
#
# ca-certificates-2026 | 144 KB    | ########## | 100%
#
#
#
#
# certifi-2026.2.25    | 148 KB    | ########## | 100%
#
#
#
#
# certifi-2026.2.25    | 148 KB    | ########## | 100%
#
# libxgboost-3.2.0     | 2.5 MB    | 6          |   6%
#
#
# conda-26.1.1         | 1.2 MB    | ##1        |  22%
# openssl-3.6.2        | 9.0 MB    | 7          |   7%
#
# libxgboost-3.2.0     | 2.5 MB    | 8          |   9%
#
#
#
#
#
#
# xgboost-3.2.0        | 15 KB     | ########## | 100%
#
#
#
#
#
#
# xgboost-3.2.0        | 15 KB     | ########## | 100%
# openssl-3.6.2        | 9.0 MB    | 7          |   8%
#
#
# conda-26.1.1         | 1.2 MB    | ##6        |  27%
#
#
#
#
#
#
# xgboost-3.2.0        | 15 KB     | ########## | 100%
#
#
# conda-26.1.1         | 1.2 MB    | ###        |  31%
# openssl-3.6.2        | 9.0 MB    | 8          |   9%
#
# libxgboost-3.2.0     | 2.5 MB    | #          |  11%
#
#
# conda-26.1.1         | 1.2 MB    | ###3       |  33%
#
#
# conda-26.1.1         | 1.2 MB    | ###5       |  36%
#
# libxgboost-3.2.0     | 2.5 MB    | #2         |  12%
# openssl-3.6.2        | 9.0 MB    | 9          |   9%
#
#
# conda-26.1.1         | 1.2 MB    | ###8       |  39%
#
# libxgboost-3.2.0     | 2.5 MB    | #4         |  14%
# openssl-3.6.2        | 9.0 MB    | #          |  11%
#
#
# conda-26.1.1         | 1.2 MB    | ####1      |  41%
#
# libxgboost-3.2.0     | 2.5 MB    | #6         |  16%
#
#
# conda-26.1.1         | 1.2 MB    | ####3      |  44%
# openssl-3.6.2        | 9.0 MB    | #1         |  11%
# openssl-3.6.2        | 9.0 MB    | #2         |  13%
#
#
# conda-26.1.1         | 1.2 MB    | ####7      |  48%
#
# libxgboost-3.2.0     | 2.5 MB    | #7         |  17%
#
# libxgboost-3.2.0     | 2.5 MB    | #9         |  19%
#
#
# conda-26.1.1         | 1.2 MB    | #####      |  50%
# openssl-3.6.2        | 9.0 MB    | #3         |  13%
#
# libxgboost-3.2.0     | 2.5 MB    | ##         |  21%
#
#
# conda-26.1.1         | 1.2 MB    | #####2     |  53%
# openssl-3.6.2        | 9.0 MB    | #5         |  15%
#
# libxgboost-3.2.0     | 2.5 MB    | ##3        |  24%
#
#
# conda-26.1.1         | 1.2 MB    | ######     |  60%
# openssl-3.6.2        | 9.0 MB    | #7         |  17%
#
# libxgboost-3.2.0     | 2.5 MB    | ##6        |  27%
#
#
# conda-26.1.1         | 1.2 MB    | ######4    |  64%
#
# libxgboost-3.2.0     | 2.5 MB    | ##9        |  29%
# openssl-3.6.2        | 9.0 MB    | #8         |  19%
#
#
# conda-26.1.1         | 1.2 MB    | ######8    |  68%
#
# libxgboost-3.2.0     | 2.5 MB    | ###1       |  31%
#
#
# conda-26.1.1         | 1.2 MB    | #######1   |  72%
#
# libxgboost-3.2.0     | 2.5 MB    | ###3       |  33%
# openssl-3.6.2        | 9.0 MB    | #9         |  20%
#
# libxgboost-3.2.0     | 2.5 MB    | ###5       |  36%
#
#
# conda-26.1.1         | 1.2 MB    | #######7   |  77%
# openssl-3.6.2        | 9.0 MB    | ##1        |  22%
#
#
# conda-26.1.1         | 1.2 MB    | ########3  |  83%
#
# libxgboost-3.2.0     | 2.5 MB    | ###9       |  39%
# openssl-3.6.2        | 9.0 MB    | ##2        |  23%
#
# libxgboost-3.2.0     | 2.5 MB    | ####1      |  42%
#
#
# conda-26.1.1         | 1.2 MB    | ########7  |  87%
# openssl-3.6.2        | 9.0 MB    | ##3        |  24%
#
# libxgboost-3.2.0     | 2.5 MB    | ####4      |  45%
#
#
# conda-26.1.1         | 1.2 MB    | #########3 |  94%
# openssl-3.6.2        | 9.0 MB    | ##4        |  25%
#
# libxgboost-3.2.0     | 2.5 MB    | ####7      |  47%
# openssl-3.6.2        | 9.0 MB    | ##5        |  26%
#
#
# conda-26.1.1         | 1.2 MB    | #########8 |  99%
#
#
# conda-26.1.1         | 1.2 MB    | ########## | 100%
#
# libxgboost-3.2.0     | 2.5 MB    | ####9      |  50%
#
# libxgboost-3.2.0     | 2.5 MB    | #####2     |  52%
# openssl-3.6.2        | 9.0 MB    | ##6        |  27%
#
# libxgboost-3.2.0     | 2.5 MB    | #####4     |  55%
# openssl-3.6.2        | 9.0 MB    | ##9        |  29%
#
# libxgboost-3.2.0     | 2.5 MB    | #####7     |  58%
# openssl-3.6.2        | 9.0 MB    | ###        |  30%
# openssl-3.6.2        | 9.0 MB    | ###1       |  32%
#
# libxgboost-3.2.0     | 2.5 MB    | ######1    |  62%
# openssl-3.6.2        | 9.0 MB    | ###2       |  33%
#
# libxgboost-3.2.0     | 2.5 MB    | ######4    |  64%
#
# libxgboost-3.2.0     | 2.5 MB    | ######7    |  67%
# openssl-3.6.2        | 9.0 MB    | ###3       |  34%
# openssl-3.6.2        | 9.0 MB    | ###4       |  35%
#
# libxgboost-3.2.0     | 2.5 MB    | #######    |  70%
# openssl-3.6.2        | 9.0 MB    | ###7       |  37%
#
# libxgboost-3.2.0     | 2.5 MB    | #######5   |  75%
#
# libxgboost-3.2.0     | 2.5 MB    | #######8   |  78%
# openssl-3.6.2        | 9.0 MB    | ###8       |  38%
# openssl-3.6.2        | 9.0 MB    | ###9       |  40%
#
# libxgboost-3.2.0     | 2.5 MB    | ########   |  81%
# openssl-3.6.2        | 9.0 MB    | ####       |  41%
#
# libxgboost-3.2.0     | 2.5 MB    | ########3  |  83%
#
# libxgboost-3.2.0     | 2.5 MB    | ########7  |  87%
# openssl-3.6.2        | 9.0 MB    | ####2      |  42%
#
# libxgboost-3.2.0     | 2.5 MB    | #########  |  90%
# openssl-3.6.2        | 9.0 MB    | ####3      |  44%
#
# libxgboost-3.2.0     | 2.5 MB    | #########3 |  93%
# openssl-3.6.2        | 9.0 MB    | ####5      |  45%
# openssl-3.6.2        | 9.0 MB    | ####6      |  46%
# openssl-3.6.2        | 9.0 MB    | ####7      |  48%
#
# libxgboost-3.2.0     | 2.5 MB    | #########6 |  97%
#
# libxgboost-3.2.0     | 2.5 MB    | ########## | 100%
# openssl-3.6.2        | 9.0 MB    | ####9      |  49%
# openssl-3.6.2        | 9.0 MB    | #####1     |  51%
# openssl-3.6.2        | 9.0 MB    | #####2     |  53%
#
#
# conda-26.1.1         | 1.2 MB    | ########## | 100%
# openssl-3.6.2        | 9.0 MB    | #####4     |  54%
# openssl-3.6.2        | 9.0 MB    | #####6     |  56%
#
# libxgboost-3.2.0     | 2.5 MB    | ########## | 100%
#
# libxgboost-3.2.0     | 2.5 MB    | ########## | 100%
# openssl-3.6.2        | 9.0 MB    | #####7     |  57%
# openssl-3.6.2        | 9.0 MB    | #####8     |  59%
# openssl-3.6.2        | 9.0 MB    | #####9     |  60%
# openssl-3.6.2        | 9.0 MB    | ######2    |  63%
# openssl-3.6.2        | 9.0 MB    | ######4    |  64%
# openssl-3.6.2        | 9.0 MB    | ######5    |  66%
# openssl-3.6.2        | 9.0 MB    | ######7    |  67%
# openssl-3.6.2        | 9.0 MB    | ######8    |  69%
# openssl-3.6.2        | 9.0 MB    | ######9    |  70%
# openssl-3.6.2        | 9.0 MB    | #######1   |  72%
# openssl-3.6.2        | 9.0 MB    | #######4   |  74%
# openssl-3.6.2        | 9.0 MB    | #######6   |  76%
# openssl-3.6.2        | 9.0 MB    | #######8   |  78%
# openssl-3.6.2        | 9.0 MB    | #######9   |  80%
# openssl-3.6.2        | 9.0 MB    | ########1  |  81%
# openssl-3.6.2        | 9.0 MB    | ########3  |  83%
# openssl-3.6.2        | 9.0 MB    | ########4  |  85%
# openssl-3.6.2        | 9.0 MB    | ########6  |  87%
# openssl-3.6.2        | 9.0 MB    | ########8  |  89%
# openssl-3.6.2        | 9.0 MB    | #########1 |  91%
# openssl-3.6.2        | 9.0 MB    | #########3 |  93%
# openssl-3.6.2        | 9.0 MB    | #########5 |  95%
# openssl-3.6.2        | 9.0 MB    | #########7 |  98%
# openssl-3.6.2        | 9.0 MB    | #########9 | 100%
# openssl-3.6.2        | 9.0 MB    | ########## | 100%
# openssl-3.6.2        | 9.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                       done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.11.0
#     latest version: 26.3.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
# For data manipulation
import numpy as np
import pandas as pd

# For data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# For displaying all of the columns in dataframes
pd.set_option('display.max_columns', None)

# For data modeling
from xgboost import XGBClassifier
from xgboost import XGBRegressor
from xgboost import plot_importance

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# For metrics and helpful functions
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score,\
f1_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.tree import plot_tree

# For saving models
import pickle
